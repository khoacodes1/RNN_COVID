# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import mean_squared_error, r2_score

# %%
random.seed(123)

# %%
df = pd.read_csv("datasets\covid19postvaxstatewidestats.csv")

df = df[df['unvaccinated_cases_per_100k'].notna()]

df = df.reset_index(drop=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\dangn\AppData\Local\Temp\ipykernel_12508\2108600221.py:1: SyntaxWarning: invalid escape sequence '\c'
#   df = pd.read_csv("datasets\covid19postvaxstatewidestats.csv")

# %%
df_unvac = df[['unvaccinated_cases_per_100k', 'unvaccinated_hosp_per_100k', 'unvaccinated_deaths_per_100k']]

df_unvac
# Out:
#      unvaccinated_cases_per_100k  unvaccinated_hosp_per_100k  \
# 0                      27.251295                    1.483401
# 1                      25.072362                    1.360519
# 2                      23.268146                    1.296892
# 3                      21.766329                    1.236441
# 4                      20.467271                    1.179528
# ..                           ...                         ...
# 778                     8.425650                    0.613146
# 779                     8.210084                    0.564715
# 780                     8.268116                    0.552060
# 781                     8.157356                    0.570069
# 782                     8.008367                    0.580428
#
#      unvaccinated_deaths_per_100k
# 0                        0.067702
# 1                        0.078033
# 2                        0.087677
# 3                        0.099877
# 4                        0.112219
# ...

# %%
def sequence_data(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), :])
        y.append(data[i+time_step,:])
    return np.array(X), np.array(y)

# %%
split_index = int(len(df_unvac) * 0.8)

train_data = df_unvac[:split_index].values
test_data = df_unvac[split_index:].values

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# train_data = scaler.fit_transform(train_data)
# test_data = scaler.transform(test_data)

X_train, y_train = sequence_data(train_data, 10)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2])

X_test, y_test = sequence_data(test_data, 10)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2])

# %%
X_train.shape
# Out:
# (615, 10, 3)

# %%
y_train.shape
# Out:
# (615, 3)

# %%
model = Sequential([LSTM(50, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu'),
                      Dense(3)])
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model.summary()

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4501.5630 - mae: 22.2982 - val_loss: 87.8803 - val_mae: 7.8292
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 818.8582 - mae: 11.5599 - val_loss: 14.1274 - val_mae: 2.6308
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 319.3351 - mae: 6.3010 - val_loss: 13.9034 - val_mae: 2.1128
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 197.6956 - mae: 4.6243 - val_loss: 4.9111 - val_mae: 1.3359
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 191.1573 - mae: 4.2633 - val_loss: 5.8486 - val_mae: 1.5914
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 88.6612 - mae: 3.4859 - val_loss: 2.5166 - val_mae: 1.0626
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 100.2078 - mae: 3.4386 - val_loss: 3.0091 - val_mae: 1.0311
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 99.9699 - mae: 2.9815 - val_loss: 6.3032 - val_mae: 1.4244
# Epoch 9/20
# ...

# %%
#Add parameters - 1 hidden
model_1 = Sequential([LSTM(50, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu'),
                      Dense(50),
                      Dense(3)])
model_1.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model_1.summary()

# %%
model_1.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2857.8696 - mae: 17.2112 - val_loss: 14.0610 - val_mae: 2.5674
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 397.4283 - mae: 6.0146 - val_loss: 3.7177 - val_mae: 1.4341
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 153.8273 - mae: 3.9818 - val_loss: 4.6079 - val_mae: 1.7850
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 79.1363 - mae: 3.5187 - val_loss: 3.0192 - val_mae: 1.3209
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.8751 - mae: 2.6968 - val_loss: 1.6826 - val_mae: 0.8326
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.4556 - mae: 1.6854 - val_loss: 1.2994 - val_mae: 0.6336
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.6312 - mae: 1.7285 - val_loss: 1.2611 - val_mae: 0.4898
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.1904 - mae: 1.4679 - val_loss: 1.5444 - val_mae: 0.7869
# Epoch 9/20
# ...

# %%
#Add parameters - 2 hidden - exhibit sign of overfitting
model_2 = Sequential([LSTM(50, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu'),
                      Dense(50),
                      Dense(50),
                      Dense(3)])
model_2.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model_2.summary()

# %%
model_2.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5210.1099 - mae: 32.5349 - val_loss: 13.7631 - val_mae: 3.0205
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 208.9284 - mae: 5.6455 - val_loss: 4.6064 - val_mae: 1.6910
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 165.3176 - mae: 4.8633 - val_loss: 2.1782 - val_mae: 1.1643
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 136.7095 - mae: 3.7489 - val_loss: 2.1849 - val_mae: 0.9038
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 171.3518 - mae: 4.1817 - val_loss: 6.4088 - val_mae: 1.7362
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 232.8601 - mae: 5.2228 - val_loss: 3.2681 - val_mae: 1.2299
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.4065 - mae: 2.8893 - val_loss: 2.0311 - val_mae: 0.9816
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.4838 - mae: 2.1172 - val_loss: 1.6426 - val_mae: 0.8395
# Epoch 9/20
# ...

# %%
#Decrease Learning Rate - 1 hidden - 0.00001 - lengthy training time with higher epochs to converge
model_3 = Sequential([LSTM(50, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu'),
                      Dense(50),
                      Dense(50),
                      Dense(3)])
model_3.compile(optimizer=Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model_3.summary()

# %%
model_3.fit(X_train, y_train, epochs=2000, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7171 - mae: 0.6206 - val_loss: 0.4054 - val_mae: 0.3651
# Epoch 2/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7696 - mae: 0.6403 - val_loss: 0.4044 - val_mae: 0.3638
# Epoch 3/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8591 - mae: 0.6012 - val_loss: 0.4121 - val_mae: 0.3707
# Epoch 4/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2968 - mae: 0.6318 - val_loss: 0.4112 - val_mae: 0.3651
# Epoch 5/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8496 - mae: 0.5536 - val_loss: 0.4068 - val_mae: 0.3591
# Epoch 6/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2655 - mae: 0.5784 - val_loss: 0.4086 - val_mae: 0.3613
# Epoch 7/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0910 - mae: 0.6382 - val_loss: 0.4097 - val_mae: 0.3637
# Epoch 8/2000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1890 - mae: 0.5935 - val_loss: 0.4158 - val_mae: 0.3652
# Epoch 9/2000
# ...

# %%
model_4 = Sequential([LSTM(128, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu'),
                      Dense(128),
                      Dense(3)])
model_4.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model_4.summary()

# %%
model_4.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1084.2137 - mae: 11.6636 - val_loss: 6.9137 - val_mae: 2.1822
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 332.1290 - mae: 6.2721 - val_loss: 8.1157 - val_mae: 1.7870
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 99.5131 - mae: 3.1736 - val_loss: 1.4339 - val_mae: 0.8296
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.0834 - mae: 2.2043 - val_loss: 3.9864 - val_mae: 1.3895
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 107.0670 - mae: 3.0819 - val_loss: 2.2540 - val_mae: 1.0187
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2360 - mae: 2.2298 - val_loss: 1.2239 - val_mae: 0.6616
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.4331 - mae: 1.5960 - val_loss: 1.1893 - val_mae: 0.7089
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.3508 - mae: 1.4996 - val_loss: 3.2130 - val_mae: 1.0412
# Epoch 9/20
# ...

# %%
model_5 = Sequential([LSTM(20, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu'),
                      Dense(20),
                      Dense(3)])
model_5.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model_5.summary()
# Out:
# C:\Users\dangn\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_13 (LSTM)                  │ (None, 20)             │         1,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model_5.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3359.9712 - mae: 18.7356 - val_loss: 156.1647 - val_mae: 7.5291
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2582.8147 - mae: 17.2053 - val_loss: 110.0542 - val_mae: 7.5774
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2357.1362 - mae: 16.9500 - val_loss: 67.4858 - val_mae: 5.6378
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1147.2249 - mae: 12.3529 - val_loss: 24.7563 - val_mae: 3.9263
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 381.4046 - mae: 7.1852 - val_loss: 7.1057 - val_mae: 2.0206
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.4445 - mae: 2.9678 - val_loss: 1.7024 - val_mae: 1.0585
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.2560 - mae: 1.8517 - val_loss: 0.9552 - val_mae: 0.7144
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.3706 - mae: 1.7227 - val_loss: 0.7542 - val_mae: 0.6736
# Epoch 9/20
# ...

# %%
model_6 = Sequential([LSTM(128, input_shape = (X_train.shape[1], X_train.shape[2]), activation = 'relu', kernel_regularizer=l2(0.001)),
                      Dense(128, kernel_regularizer=l2(0.001)),
                      Dropout(0.05),
                      Dense(3)])
model_6.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model_6.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_18 (LSTM)                  │ (None, 128)            │        67,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,483 (330.01 KB)
#  Trainable params: 84,483 (330.01 KB)
# ...

# %%
model_6.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3239.8052 - mae: 19.9534 - val_loss: 10.6070 - val_mae: 2.1663
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 947.0593 - mae: 8.9386 - val_loss: 13.6061 - val_mae: 2.9107
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 438.5421 - mae: 7.1531 - val_loss: 7.1886 - val_mae: 1.9016
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 558.9070 - mae: 7.0407 - val_loss: 6.9007 - val_mae: 1.7669
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 222.4203 - mae: 5.0309 - val_loss: 2.7590 - val_mae: 0.9104
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 166.9262 - mae: 4.1455 - val_loss: 3.0730 - val_mae: 1.3432
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 92.4607 - mae: 3.6783 - val_loss: 1.5121 - val_mae: 0.7028
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 193.0145 - mae: 4.1524 - val_loss: 2.3144 - val_mae: 0.9249
# Epoch 9/20
# ...
